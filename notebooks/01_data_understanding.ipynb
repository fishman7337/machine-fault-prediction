# %% [markdown]
# # 01 Data Understanding
#
# This notebook inspects the raw factory dataset and confirms the schema, missing values, and target balance before any modeling work.

# %%
from fault_prediction.config import DEFAULT_DATA_PATH
from fault_prediction.data import load_factory_data, target_distribution, validate_schema

df = load_factory_data(DEFAULT_DATA_PATH)
validate_schema(df)
df.shape

# %%
df.head()

# %%
df.dtypes.to_frame(name="dtype")

# %%
df.isna().sum().sort_values(ascending=False).to_frame(name="missing_values")

# %%
target_distribution(df)

# %%
df.describe(include="all").T

# %% [markdown]
# ## Handoff
#
# Use `02_feature_engineering_and_statistics.ipynb` next to review engineered features and p-value based feature association tests.
